# %% [markdown]
# # Data Science Tools and Ecosystem
# 2-title.png:![Screenshot (16).png](data:image/png;base64,...)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# 3-intro.png:![Screenshot (17).png](data:image/png;base64,...)

# %% [markdown]
# **Objectives:**
# + Creating a notebook
# + Creating markdown and code cells
# + Inserting an image in markdown cells
# + Executing code
#
# 10-objectives.png:![Screenshot (24).png](data:image/png;base64,...)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. R
#
# 4-dslanguages.png:![Screenshot (18).png](data:image/png;base64,...)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. GGally
# 2. Pandas
# 3. Seaborn
#
# 5-dslibraries.png:![Screenshot (19).png](data:image/png;base64,...)

# %% [markdown]
# | Data Science Tools |
#  --------------------
# | Apache Spark |
# | RStudio |
# | Jupyter Lab |
#
# 6-dstools.png:![Screenshot (20).png](data:image/png;base64,...)

# %% [markdown]
# ###Below are a few examples of evaluating arithmetic expressions in Python
#
# 7-introarithmetic.png:![Screenshot (21).png](data:image/png;base64,...)

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# 8-multiplyandaddintegers.png:![Screenshot (22).png](data:image/png;base64,...)

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# 9-hourstominutes.png:![Screenshot (23).png](data:image/png;base64,...)

# %% [markdown]
# ##Author:
# Mey Aya
#
# 11-authordetails.png:![Screenshot (25).png](data:image/png;base64,...)
